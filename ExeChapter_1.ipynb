# %% [markdown]
# # Exercicios Capitulo 1

# %% [markdown]
# **1.1** Calcule a área de um círculo de raio 2. Assuma pi = 3.14.

# %%
def AreaCirc(r = 2):
    return 3.1415 * (r**2)

AreaCirc(r = 2)
# Out:
# 12.566

# %% [markdown]
# **1.2** Escreva uma função que verifica se um número é par. Se for, imprima uma mensagem. Se não for, imprima outra mensagem.

# %%
def ParImpar(n):
    
    if n % 2 == 0:
        print('{} é par'.format(n))

    else:
        print('{} é impar'.format(n))

ParImpar(3)
# Out:
# 3 é impar

# %% [markdown]
# **1.3** No exercício acima, se o número for par, verifique se ele é múltiplo de 4. Se for, exiba uma mensagem diferente.

# %%
def ParImpar(n, m = 4):
    
    if n % m == 0 and n % 2 == 0:                            
        print('{} é par, e é multiplo de {}'.format(n,m))
       
    else:              
        if n % 2 == 0:
            print('{} é par'.format(n))
        else:
            print('{} é impar'.format(n))
            
ParImpar(16)
# Out:
# 16 é par, e é multiplo de 4

# %% [markdown]
# **1.4** Escreva um código que imprima os elementos menores que 5 na seguinte lista:

# %%
a = [1, 4, 2, 3, 2, 1, 5, 8, 5, 7, -1, 0, 23]

def selec(a, k = 5):
    b = []

    for i in range(0, len(a)):
        if a[i] < 5:
            b.append(a[i])
        else:
            continue

    return b

selec(a, k = 5)
# Out:
# [1, 4, 2, 3, 2, 1, -1, 0]

# %% [markdown]
# **1.5** Escreva um código que encontra todos os divisores do número 42:

# %%
def divisor(m = 42):
    a = []
    for i in range(1,m):
        if m % i == 0:
            a.append(i)
    
    a.append(m)
    
    return a

divisor(m = 42)
# Out:
# [1, 2, 3, 6, 7, 14, 21, 42]

# %% [markdown]
# **1.6** Calcule a multiplicação das duas matrizes abaixo sem usar laços:

# %%
a = [[2, 3], [4, 2]]
b = [[2, 0], [1, 2]]

def Prod2x2(a,b):
    return [[a[0][0]*b[0][0] + a[0][1]*b[1][0], a[0][0]*b[0][1] + a[0][1]*b[1][1]],[a[1][0]*b[0][0] + a[1][1]*b[1][0],
    a[1][0]*b[0][1] + a[1][1]*b[1][1]]]

Prod2x2(a,b)
# Out:
# [[7, 6], [10, 4]]

# %% [markdown]
# **1.7** Calcule a multiplicação das duas matrizes acima usando laços:

# %%
def Prodlac2x2(a,b):
    ab = [[0,0],[0,0]]
    for i in range(0, 2):
        for j in range(0, 2): 
            for k in range(0, 2): # For para realizar as somas , dentro de cada entrada da matriz
                ab[i][j] += a[i][k]*b[k][j]
    return ab 

Prodlac2x2(a,b)
# Out:
# [[7, 6], [10, 4]]

# %% [markdown]
# **1.8** Calcule o fatorial de 5 usando algum tipo de laço:

# %%
def fat(n):
    fator = 1
    for i in range(1, n + 1):
        fator = i * fator
    return fator

fat(5)
# Out:
# 120

# %% [markdown]
# **1.9** Dada uma variável $ X \sim N(0,4) $, calcule o valor da fdp para o valor 2:

# %%
def fdp_normal(x, mean = 0, var = 4, n = 100):
    import numpy as np

    return (1/(var * 3.1415 * 2)**(1/2) * np.exp(-((x - mean)**2)/(2 * var)))

fdp_normal(x = 2, mean = 0, var = 4)
# Out:
# 0.12098714638267746

# %% [markdown]
# **1.10** Calcule a distância Euclidiana dos seguintes vetores:

# %%
a, b = [1, 0, 1], [-1, 2, 3]

def d(a,b):
    d = 0
    for i in range(0, len(a)):
        d = (a[i]*b[i])**(2) + d
    return (d)**(1/2)

d([1,2,3],[3,2,1])
# Out:
# 5.830951894845301

# %% [markdown]
# **1.11** Imprima as potências de 2, começando em  20 , enquanto o resultado for menor do que 2000:

# %%
def zero(x, min = 20, max = 2000, n = 10):
    for i in range(1,n + 1):
        if x**(i) < min and x**(i) > max:
            break
        else:
            print('{} é equivalente á {} elevado á {}'.format(x**(i), x, i))

zero(2)
# Out:
# 2 é equivalente á 2 elevado á 1
# 4 é equivalente á 2 elevado á 2
# 8 é equivalente á 2 elevado á 3
# 16 é equivalente á 2 elevado á 4
# 32 é equivalente á 2 elevado á 5
# 64 é equivalente á 2 elevado á 6
# 128 é equivalente á 2 elevado á 7
# 256 é equivalente á 2 elevado á 8
# 512 é equivalente á 2 elevado á 9
# 1024 é equivalente á 2 elevado á 10

# %% [markdown]
# **1.12** Verifique se o número 79 é primo:

# %%
'''
Tentei fazer de uma forma diferente , utilizando outras coisas, existem diversas outras formas, so pra constar kk 

'''

def PrimoNumber(x):
    a = []
    for i in range(2, x):
        if x % i == 0:
            a.append(1)
        else:
            a.append(0)
    if sum(a) == 0:
        print('{} é primo'.format(x))
    else: 
        print('{} não é primo'.format(x))
    
PrimoNumber(79)
# Out:
# 79 é primo

# %% [markdown]
# **1.13** Escreva uma linha de código Python que gere uma lista apenas com os valores divisíveis por 2 e por 5 na lista abaixo:

# %%
a = [1, 4, 10, 13, 15, 16, 20, 28, 30]
b = []
for i in range(0, len(a)):
    if a[i] % 2 == 0 and a[i] % 5 == 0:
        b.append(a[i])

b
# Out:
# [10, 20, 30]

# %% [markdown]
# **1.14** Escreva um laço que resulte no sétimo elemento da sequência de Fibonacci (lembrando que em Python os índices começam em 0):

# %%
def fib(n):
    a = 0
    b = 1
    i = 0
    if n == 0:
        return a
    while i + 1 < n:
        a = a + b
        temp = b
        b = a
        a = temp
        i += 1
    
    return a

fib(7)
# Out:
# 8

# %% [markdown]
# **1.15** Escreva uma função que calcule o raio de um círculo, dado um valor de raio. Peça um valor de raio ao usuário e calcule o valor da função:

# %% [markdown]
# _**(Respondido no primeiro Exercicio)**_

# %% [markdown]
# **1.16** Escreva uma função que recebe uma lista e um valor e retorna uma sub-lista apenas com os elementos menores do que o valor fornecido:

# %%
def MinList(x, a):
    b = []
    for i in range(len(x)):
        if x[i] < a:
            b.append(x[i])
    return b

MinList([1,52,25,2,43,0,1,2],26)
# Out:
# [1, 25, 2, 0, 1, 2]

# %% [markdown]
# **1.18** Escreva uma função que recebe um número e valores de média e de variância e calcula a fdp das distribuições normais correspondentes às médias e às variâncias fornecidas:

# %%
''' 
Ja resolvido no Exercicio 1.12 

'''

def PrimoNumber(x):
    a = []
    for i in range(2, x):
        if x % i == 0:
            a.append(1)
        else:
            a.append(0)
    if sum(a) == 0:
        print('{} é primo'.format(x))
    else: 
        print('{} não é primo'.format(x))
    
PrimoNumber(7)
# Out:
# 7 é primo

# %% [markdown]
# **1.20** Faça uma função que retorna todos os divisores de um número:

# %%
''' 
Ja resolvido no Exercicio 1.5 

'''

def divisor(m = 42):
    a = []
    for i in range(1,m):
        if m % i == 0:
            a.append(i)
    
    a.append(m)
    
    return a

divisor(m = 100)
# Out:
# [1, 2, 4, 5, 10, 20, 25, 50, 100]

# %% [markdown]
# **1.21** Faça uma função que calcula o fatorial de um número:

# %%
''' 
Ja resolvido no Exercicio 1.8

'''

def fat(n):
    fator = 1
    for i in range(1, n + 1):
        fator  = i * fator
    return fator

fat(4)
# Out:
# 24

# %% [markdown]
# **1.22** Faça uma função que calcula $ P(X=x) $, tal que $ X\sim Binomial(n,p)$. Escreva uma função auxiliar que calcula $ {n}\choose{x} $ para chamar na função principal:

# %%
def ProbBin(x, n, p):
    def fat(n):
        fator = 1
        for i in range(1, n + 1):
            fator = i * fator
        return fator
    
    def comb(n,x):
        return (fat(n))/(fat(x) * (fat(n - x)))

    return comb(n,x) * (p**(x)) * ((1 - p)**(n - x))

ProbBin(x = 6, n = 7, p = 0.9)
# Out:
# 0.37200869999999997

# %% [markdown]
# **1.23** Escreva uma função que calcula  $ P(X=x) $  ou  $ P(X<=x) $  (o usuário escolhe), tal que  $ X\sim Binomial(n ,p) $:
#
# <p>
#
# **Argumentos :**
#
# <p>
#
# **x :** Quantidade de sucessos do evento;
#
# <p>
#
# **p :** Probabilidade de sucesso;
#
# <p>
#
# **n :** Quantidade de repetições de eventos de $ Bernoulli $;
#
# <p>
#
# **ord :** Será considerado ** 0 ** para $ P(X = x) $ e ** 1 ** para $ P(X <= x) $, ou **ord = 2** para $ P(X > x) $ ou **ord > 2** para $ P(X >= x) $.

# %%
def ProbBin01(x, n, p, ord = 0):
    if ord == 0:
        return ProbBin(x, n, p)

    else:
        if ord == 1:
            prob = 0
            for j in range(0, x + 1):
                prob = ProbBin(j, n, p) + prob
        
            return prob
        else:
            if ord == 2:
                return 1 - ProbBin01(x, n, p, ord = 1)
            else: 
                return ProbBin01(x, n, p, ord = 1) + ProbBin01(x, n, p, ord = 0)

ProbBin01(x = 2, n = 3, ord = 2, p = 0.9)
# Out:
# 0.7290000000000001

# %% [markdown]
# **1.24** Escreva uma função que recebe uma lista, um valor e uma função de comparação e retorna uma sub-lista apenas com os elementos para os quais a função fornecida retorna True:

# %%
'''
Pelo o que eu entendi, deve-se criar uma função , cujo um argumento utiliza-se de uma função
'''
# Out:
# 22.666666666666668

# %% [markdown]
# **1.25 (Desafio: Recursão)** Recursão é uma abordagem para solucionar problemas que envolve dividir a tarefa em partes menores do mesmo tipo, i.e. é uma abordagem do tipo dividir-para-conquistar. Do ponto de vista computacional, um problema resolvido usando recursão envolve uma função que chama a si mesma até que o problema seja resolvido. Uma parte importante desse tipo de solução é a definição do ponto de parada da recursão, quando a função para de chamar a si mesma e começar a retornar os valores para as chamadas mais "acima". Vejamos um exemplo de recursão para o cálculo do fatorial de um número n:

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n - 1)

factorial()
